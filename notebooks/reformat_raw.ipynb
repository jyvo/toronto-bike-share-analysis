# %%
from utils.path import get_git_root
from utils.load_data import LoadData
from utils.preprocessing import normalize_column_names, normalize_datetimes, calc_trip_duration
import pandas as pd
import numpy as np

data_path = get_git_root() / "data" / "raw"
data = LoadData(data_path)
data.get_data_dirs()
# Out:
# ['bikeshare-ridership-2014-2015',
#  'bikeshare-ridership-2016',
#  'bikeshare-ridership-2017',
#  'bikeshare-ridership-2018',
#  'bikeshare-ridership-2019',
#  'bikeshare-ridership-2020',
#  'bikeshare-ridership-2021',
#  'bikeshare-ridership-2022',
#  'bikeshare-ridership-2023',
#  'bikeshare-ridership-2024',
#  'bikeshare-ridership-readme']

# %%
avoid_dirs = ['bikeshare-ridership-2014-2015', 'bikeshare-ridership-2016', 'bikeshare-ridership-readme']
data.load_datasets(omit=avoid_dirs)
# Out:
# Dataset 'bikeshare-ridership-2017' loaded.
# Dataset 'bikeshare-ridership-2018' loaded.
# Dataset 'bikeshare-ridership-2019' loaded.
# Dataset 'bikeshare-ridership-2020' loaded.
# Dataset 'bikeshare-ridership-2021' loaded.
# Dataset 'bikeshare-ridership-2022' loaded.
# Dataset 'bikeshare-ridership-2023' loaded.
# Dataset 'bikeshare-ridership-2024' loaded.
# All datasets loaded

# %%
data.list_datasets()
# Out:
# {'bikeshare-ridership-2017': <utils.load_data.Dataset at 0x22e7f355150>,
#  'bikeshare-ridership-2018': <utils.load_data.Dataset at 0x22e7e235590>,
#  'bikeshare-ridership-2019': <utils.load_data.Dataset at 0x22e7f354e90>,
#  'bikeshare-ridership-2020': <utils.load_data.Dataset at 0x22e0a53f5d0>,
#  'bikeshare-ridership-2021': <utils.load_data.Dataset at 0x22e2203a990>,
#  'bikeshare-ridership-2022': <utils.load_data.Dataset at 0x22e7ebb4890>,
#  'bikeshare-ridership-2023': <utils.load_data.Dataset at 0x22e30bd4490>,
#  'bikeshare-ridership-2024': <utils.load_data.Dataset at 0x22e646aaa10>}

# %%
for name, ds in data.list_datasets().items():
    print(name)
    # optimize so it doesnt rerun multiple loops
    ds_cols = [set(df.columns.tolist()) for df in ds.get_data_files()]
    
    union_cols = ds.get_unique_cols()
    intersection_cols = set.intersection(*ds_cols)
    difference_cols = union_cols - intersection_cols
    files_missing_col = [key for key, df in ds.list_data_files().items() if not difference_cols.issubset(df.columns)]
    
    print(f"union: {union_cols}")
    print(f"intersection: {intersection_cols}")
    print(f"difference: {difference_cols}")
    print(f"missing in: {files_missing_col}\n")
# Out:
# bikeshare-ridership-2017
# union: {'trip_start_time', 'trip_stop_time', 'to_station_id', 'to_station_name', 'trip_duration_seconds', 'user_type', 'trip_id', 'from_station_id', 'from_station_name'}
# intersection: {'trip_start_time', 'trip_stop_time', 'to_station_name', 'user_type', 'trip_duration_seconds', 'trip_id', 'from_station_name'}
# difference: {'to_station_id', 'from_station_id'}
# missing in: ['Bikeshare Ridership (2017 Q3).csv', 'Bikeshare Ridership (2017 Q4).csv']
#
# bikeshare-ridership-2018
# union: {'trip_start_time', 'trip_stop_time', 'to_station_id', 'to_station_name', 'trip_duration_seconds', 'user_type', 'trip_id', 'from_station_id', 'from_station_name'}
# intersection: {'trip_start_time', 'to_station_id', 'trip_stop_time', 'to_station_name', 'trip_duration_seconds', 'user_type', 'trip_id', 'from_station_id', 'from_station_name'}
# difference: set()
# missing in: []
#
# bikeshare-ridership-2019
# union: {'Bike Id', 'End Time', 'End Station Name', 'Trip  Duration', 'End Station Id', 'Trip Id', 'Start Station Name', 'User Type', 'Start Station Id', 'Start Time'}
# intersection: {'Bike Id', 'End Time', 'End Station Name', 'Trip  Duration', 'End Station Id', 'Trip Id', 'Start Station Name', 'User Type', 'Start Station Id', 'Start Time'}
# difference: set()
# missing in: []
#
# bikeshare-ridership-2020
# union: {'Bike Id', 'End Time', 'End Station Name', 'Trip  Duration', 'End Station Id', 'Trip Id', 'Start Station Name', 'User Type', 'Start Station Id', 'Start Time'}
# intersection: {'Bike Id', 'End Time', 'End Station Name', 'Trip  Duration', 'End Station Id', 'Trip Id', 'Start Station Name', 'User Type', 'Start Station Id', 'Start Time'}
# difference: set()
# missing in: []
#
# bikeshare-ridership-2021
# union: {'Bike Id', 'End Time', 'End Station Name', 'Trip  Duration', 'End Station Id', 'Trip Id', 'Start Station Name', 'User Type', 'Start Station Id', 'Start Time'}
# intersection: {'Bike Id', 'End Time', 'End Station Name', 'Trip  Duration', 'End Station Id', 'Trip Id', 'Start Station Name', 'User Type', 'Start Station Id', 'Start Time'}
# difference: set()
# missing in: []
#
# bikeshare-ridership-2022
# union: {'Bike Id', 'End Time', 'End Station Name', 'Trip  Duration', 'End Station Id', 'Trip Id', 'Start Station Name', 'User Type', 'Start Station Id', 'Start Time'}
# intersection: {'Bike Id', 'End Time', 'End Station Name', 'Trip  Duration', 'End Station Id', 'Trip Id', 'Start Station Name', 'User Type', 'Start Station Id', 'Start Time'}
# difference: set()
# missing in: []
#
# bikeshare-ridership-2023
# union: {'Bike Id', 'End Time', 'End Station Name', 'Trip  Duration', 'End Station Id', 'Trip Id', 'Start Station Name', 'User Type', 'Start Station Id', 'Start Time'}
# intersection: {'Bike Id', 'End Time', 'End Station Name', 'Trip  Duration', 'End Station Id', 'Trip Id', 'Start Station Name', 'User Type', 'Start Station Id', 'Start Time'}
# difference: set()
# missing in: []
#
# bikeshare-ridership-2024
# union: {'Bike Id', 'End Time', 'End Station Name', 'Trip  Duration', 'End Station Id', 'Trip Id', 'Start Station Name', 'Model', 'User Type', 'Start Station Id', 'Start Time'}
# intersection: {'Bike Id', 'End Time', 'End Station Name', 'Trip  Duration', 'End Station Id', 'Trip Id', 'Start Station Name', 'User Type', 'Start Station Id', 'Start Time'}
# difference: {'Model'}
# missing in: ['Bike share ridership 2024-01.csv']

# %%
# rename first, reorder at the end
column_mapping = {
    'trip_id': 'Trip Id', 
    'trip_duration_seconds': 'Trip  Duration', 
    'from_station_id': 'Start Station Id', 
    'trip_start_time': 'Start Time', 
    'from_station_name': 'Start Station Name', 
    'to_station_id': 'End Station Id', 
    'trip_stop_time': 'End Time', 
    'to_station_name': 'End Station Name',
    'bike_id': 'Bike Id', 
    'user_type': 'User Type',
    'model': 'Model'}

column_order = normalize_column_names(pd.Index(list(column_mapping.values())))

for ds in data.get_datasets():
    for df in ds.get_data_files():
        df.rename(columns=column_mapping, inplace=True)
        df.columns = normalize_column_names(df.columns)
    print(ds.get_unique_cols())
# Out:
# {'end_time', 'start_time', 'end_station_name', 'start_station_id', 'user_type', 'trip_id', 'trip_duration', 'end_station_id', 'start_station_name'}
# {'end_time', 'start_time', 'end_station_name', 'start_station_id', 'user_type', 'trip_id', 'trip_duration', 'end_station_id', 'start_station_name'}
# {'end_time', 'start_time', 'bike_id', 'end_station_name', 'start_station_id', 'user_type', 'trip_id', 'trip_duration', 'end_station_id', 'start_station_name'}
# {'end_time', 'start_time', 'bike_id', 'end_station_name', 'start_station_id', 'user_type', 'trip_id', 'trip_duration', 'end_station_id', 'start_station_name'}
# {'end_time', 'start_time', 'bike_id', 'end_station_name', 'start_station_id', 'user_type', 'trip_id', 'trip_duration', 'end_station_id', 'start_station_name'}
# {'end_time', 'start_time', 'bike_id', 'end_station_name', 'start_station_id', 'user_type', 'trip_id', 'trip_duration', 'end_station_id', 'start_station_name'}
# {'end_time', 'start_time', 'bike_id', 'end_station_name', 'start_station_id', 'user_type', 'trip_id', 'trip_duration', 'end_station_id', 'start_station_name'}
# {'end_time', 'start_time', 'bike_id', 'end_station_name', 'start_station_id', 'user_type', 'model', 'trip_id', 'trip_duration', 'end_station_id', 'start_station_name'}

# %%
# check dtype consistency
from collections import defaultdict

ds_col_dtypes = {}
for ds in data.get_datasets():    
    col_dtypes = defaultdict(set)
    for df in ds.get_data_files():
        for col, dtype in df.dtypes.items():
            col_dtypes[col].add(dtype)
    col_dtypes = dict(col_dtypes)
    
    print(f"{ds.get_name()}")
    print(col_dtypes)
    print()
    ds_col_dtypes[ds.get_name()] = col_dtypes

summary_dtypes = {k: set().union(*(col.get(k, set()) for col in ds_col_dtypes.values())) for k in {k for v in ds_col_dtypes.values() for k in v}}

print(f"Summary\n{summary_dtypes}\n")

summary_conflicts = {k: v for k, v in summary_dtypes.items() if len(summary_dtypes[k]) > 1}
print(f"Conflicting Column\n{summary_conflicts}")
# Out:
# bikeshare-ridership-2017
# {'trip_id': {dtype('int64')}, 'start_time': {dtype('O')}, 'end_time': {dtype('O')}, 'trip_duration': {dtype('int64')}, 'start_station_id': {dtype('int64')}, 'start_station_name': {dtype('O')}, 'end_station_id': {dtype('int64')}, 'end_station_name': {dtype('O')}, 'user_type': {dtype('O')}}
#
# bikeshare-ridership-2018
# {'trip_id': {dtype('int64')}, 'trip_duration': {dtype('int64')}, 'start_station_id': {dtype('int64')}, 'start_time': {dtype('O')}, 'start_station_name': {dtype('O')}, 'end_time': {dtype('O')}, 'end_station_id': {dtype('int64')}, 'end_station_name': {dtype('O')}, 'user_type': {dtype('O')}}
#
# bikeshare-ridership-2019
# {'trip_id': {dtype('int64')}, 'trip_duration': {dtype('float64')}, 'start_station_id': {dtype('int64')}, 'start_time': {dtype('O')}, 'start_station_name': {dtype('O')}, 'end_station_id': {dtype('int64'), dtype('float64')}, 'end_time': {dtype('O')}, 'end_station_name': {dtype('O')}, 'bike_id': {dtype('int64')}, 'user_type': {dtype('O')}}
#
# bikeshare-ridership-2020
# {'trip_id': {dtype('int64')}, 'trip_duration': {dtype('int64')}, 'start_station_id': {dtype('int64'), dtype('O')}, 'start_time': {dtype('O')}, 'start_station_name': {dtype('O')}, 'end_station_id': {dtype('float64'), dtype('O')}, 'end_time': {dtype('O')}, 'end_station_name': {dtype('O')}, 'bike_id': {dtype('int64'), dtype('float64'), dtype('O')}, 'user_type': {dtype('O')}}
#
# bikeshare-ridership-2021
# {'trip_id': {dtype('int64')}, 'trip_duration': {dtype('int64')}, 'start_station_id': {dtype('int64')}, 'start_time': {dtype('O')}, 'start_station_name': {dtype('O')}, 'end_station_id': {dtype('float64')}, 'end_time': {dtype('O')}, 'end_station_name': {dtype('O')}, 'bike_id': {dtype('int64'), dtype('float64')}, 'user_type': {dtype('O')}}
#
# bikeshare-ridership-2022
# {'trip_id': {dtype('int64')}, 'trip_duration': {dtype('int64')}, 'start_station_id': {dtype('int64')}, 'start_time': {dtype('O')}, 'start_station_name': {dtype('O')}, 'end_station_id': {dtype('float64')}, 'end_time': {dtype('O')}, 'end_station_name': {dtype('O')}, 'bike_id': {dtype('int64')}, 'user_type': {dtype('O')}}
#
# bikeshare-ridership-2023
# {'trip_id': {dtype('int64')}, 'trip_duration': {dtype('int64')}, 'start_station_id': {dtype('int64')}, 'start_time': {dtype('O')}, 'start_station_name': {dtype('O')}, 'end_station_id': {dtype('float64')}, 'end_time': {dtype('O')}, 'end_station_name': {dtype('O')}, 'bike_id': {dtype('int64')}, 'user_type': {dtype('O')}}
#
# bikeshare-ridership-2024
# {'trip_id': {dtype('int64')}, 'trip_duration': {dtype('int64')}, 'start_station_id': {dtype('int64')}, 'start_time': {dtype('O')}, 'start_station_name': {dtype('O')}, 'end_station_id': {dtype('int64'), dtype('float64')}, 'end_time': {dtype('O')}, 'end_station_name': {dtype('O')}, 'bike_id': {dtype('int64')}, 'user_type': {dtype('O')}, 'model': {dtype('O')}}
#
# Summary
# {'end_time': {dtype('O')}, 'start_time': {dtype('O')}, 'bike_id': {dtype('float64'), dtype('O'), dtype('int64')}, 'end_station_name': {dtype('O')}, 'start_station_id': {dtype('int64'), dtype('O')}, 'user_type': {dtype('O')}, 'model': {dtype('O')}, 'trip_id': {dtype('int64')}, 'trip_duration': {dtype('int64'), dtype('float64')}, 'end_station_id': {dtype('float64'), dtype('O'), dtype('int64')}, 'start_station_name': {dtype('O')}}
#
# Conflicting Column
# {'bike_id': {dtype('float64'), dtype('O'), dtype('int64')}, 'start_station_id': {dtype('int64'), dtype('O')}, 'trip_duration': {dtype('int64'), dtype('float64')}, 'end_station_id': {dtype('float64'), dtype('O'), dtype('int64')}}

# %%
map_conflicts = defaultdict(lambda: defaultdict(set))

for name, col_dtypes in ds_col_dtypes.items():
    for col, dtypes in col_dtypes.items():
        if col in summary_conflicts:
            for dtype in dtypes:
                if dtype in summary_conflicts[col]:
                    map_conflicts[col][dtype].add(name)
map_conflicts = dict(map_conflicts)
map_conflicts
# Out:
# {'trip_duration': defaultdict(set,
#              {dtype('int64'): {'bikeshare-ridership-2017',
#                'bikeshare-ridership-2018',
#                'bikeshare-ridership-2020',
#                'bikeshare-ridership-2021',
#                'bikeshare-ridership-2022',
#                'bikeshare-ridership-2023',
#                'bikeshare-ridership-2024'},
#               dtype('float64'): {'bikeshare-ridership-2019'}}),
#  'start_station_id': defaultdict(set,
#              {dtype('int64'): {'bikeshare-ridership-2017',
#                'bikeshare-ridership-2018',
#                'bikeshare-ridership-2019',
#                'bikeshare-ridership-2020',
#                'bikeshare-ridership-2021',
#                'bikeshare-ridership-2022',
#                'bikeshare-ridership-2023',
#                'bikeshare-ridership-2024'},
#               dtype('O'): {'bikeshare-ridership-2020'}}),
#  'end_station_id': defaultdict(set,
#              {dtype('int64'): {'bikeshare-ridership-2017',
#                'bikeshare-ridership-2018',
#                'bikeshare-ridership-2019',
#                'bikeshare-ridership-2024'},
#               dtype('float64'): {'bikeshare-ridership-2019',
#                'bikeshare-ridership-2020',
#                'bikeshare-ridership-2021',
#                'bikeshare-ridership-2022',
#                'bikeshare-ridership-2023',
#                'bikeshare-ridership-2024'},
#               dtype('O'): {'bikeshare-ridership-2020'}}),
#  'bike_id': defaultdict(set,
#              {dtype('int64'): {'bikeshare-ridership-2019',
#                'bikeshare-ridership-2020',
#                'bikeshare-ridership-2021',
#                'bikeshare-ridership-2022',
#                'bikeshare-ridership-2023',
#                'bikeshare-ridership-2024'},
#               dtype('float64'): {'bikeshare-ridership-2020',
#                'bikeshare-ridership-2021'},
#               dtype('O'): {'bikeshare-ridership-2020'}})}

# %%
# check for missing values
for ds in data.get_datasets():
    for name, df in ds.list_data_files().items():
        num_missing = set(df.isnull().sum().tolist())
        num_missing.discard(0)
        if len(num_missing) > 0:
            print(name)
            print(df.isnull().sum())
            print()
# Out:
# Bikeshare Ridership (2017 Q4).csv
# trip_id               0
# start_time            0
# end_time              0
# trip_duration         0
# start_station_name    0
# end_station_name      1
# user_type             0
# dtype: int64
#
# 2019-Q1.csv
# trip_id               0
# trip_duration         7
# start_station_id      0
# start_time            0
# start_station_name    0
# end_station_id        0
# end_time              0
# end_station_name      0
# bike_id               0
# user_type             0
# dtype: int64
#
# 2019-Q2.csv
# trip_id               0
# trip_duration         4
# start_station_id      0
# start_time            0
# start_station_name    0
# end_station_id        1
# end_time              0
# end_station_name      1
# bike_id               0
# user_type             0
# dtype: int64
#
# 2019-Q3.csv
# trip_id                0
# trip_duration          3
# start_station_id       0
# start_time             0
# start_station_name     0
# end_station_id        19
# end_time               0
# end_station_name      19
# bike_id                0
# user_type              0
# dtype: int64
#
# 2019-Q4.csv
# trip_id                 0
# trip_duration           2
# start_station_id        0
# start_time              0
# start_station_name      0
# end_station_id        434
# end_time                0
# end_station_name      434
# bike_id                 0
# user_type               0
# dtype: int64
#
# 2020-01.csv
# trip_id                0
# trip_duration          0
# start_station_id       0
# start_time             0
# start_station_name     0
# end_station_id        88
# end_time               0
# end_station_name      88
# bike_id                0
# user_type              0
# dtype: int64
#
# 2020-02.csv
# trip_id                0
# trip_duration          0
# start_station_id       0
# start_time             0
# start_station_name     0
# end_station_id        54
# end_time               0
# end_station_name      54
# bike_id                0
# user_type              0
# dtype: int64
#
# 2020-03.csv
# trip_id                0
# trip_duration          0
# start_station_id       0
# start_time             0
# start_station_name     0
# end_station_id        67
# end_time               0
# end_station_name      67
# bike_id                0
# user_type              0
# dtype: int64
#
# 2020-04.csv
# trip_id                0
# trip_duration          0
# start_station_id       0
# start_time             0
# start_station_name     0
# end_station_id        44
# end_time               0
# end_station_name      44
# bike_id                0
# user_type              0
# dtype: int64
#
# 2020-05.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name      0
# end_station_id        164
# end_time                0
# end_station_name      164
# bike_id                 0
# user_type               0
# dtype: int64
#
# 2020-06.csv
# trip_id                0
# trip_duration          0
# start_station_id       0
# start_time             0
# start_station_name     0
# end_station_id        75
# end_time               0
# end_station_name      75
# bike_id                0
# user_type              0
# dtype: int64
#
# 2020-07.csv
# trip_id                0
# trip_duration          0
# start_station_id       0
# start_time             0
# start_station_name     0
# end_station_id        84
# end_time               0
# end_station_name      84
# bike_id                0
# user_type              0
# dtype: int64
#
# 2020-08.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name      0
# end_station_id        115
# end_time                0
# end_station_name      115
# bike_id                 0
# user_type               0
# dtype: int64
#
# 2020-09.csv
# trip_id                0
# trip_duration          0
# start_station_id       0
# start_time             0
# start_station_name     0
# end_station_id        61
# end_time               0
# end_station_name      61
# bike_id                0
# user_type              0
# dtype: int64
#
# 2020-10.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name    164
# end_station_id         60
# end_time                0
# end_station_name      202
# bike_id                 0
# user_type             249
# dtype: int64
#
# 2020-11.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name    392
# end_station_id        263
# end_time                0
# end_station_name      636
# bike_id                 0
# user_type               0
# dtype: int64
#
# 2020-12.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name    237
# end_station_id        226
# end_time                0
# end_station_name      459
# bike_id                73
# user_type               0
# dtype: int64
#
# Bike share ridership 2021-01.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name    302
# end_station_id        313
# end_time                0
# end_station_name      612
# bike_id               203
# user_type               0
# dtype: int64
#
# Bike share ridership 2021-02.csv
# trip_id                0
# trip_duration          0
# start_station_id       0
# start_time             0
# start_station_name     0
# end_station_id        30
# end_time               0
# end_station_name      30
# bike_id                0
# user_type              0
# dtype: int64
#
# Bike share ridership 2021-03.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name      0
# end_station_id        152
# end_time                0
# end_station_name      152
# bike_id                 0
# user_type               0
# dtype: int64
#
# Bike share ridership 2021-04.csv
# trip_id                0
# trip_duration          0
# start_station_id       0
# start_time             0
# start_station_name     0
# end_station_id        76
# end_time               0
# end_station_name      76
# bike_id                0
# user_type              0
# dtype: int64
#
# Bike share ridership 2021-05.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name      0
# end_station_id        145
# end_time                0
# end_station_name      145
# bike_id                 0
# user_type               0
# dtype: int64
#
# Bike share ridership 2021-06.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name      0
# end_station_id        149
# end_time                0
# end_station_name      149
# bike_id                 0
# user_type               0
# dtype: int64
#
# Bike share ridership 2021-07.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name      0
# end_station_id        284
# end_time                0
# end_station_name      284
# bike_id                 0
# user_type               0
# dtype: int64
#
# Bike share ridership 2021-08.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name      0
# end_station_id        233
# end_time                0
# end_station_name      233
# bike_id                 0
# user_type               0
# dtype: int64
#
# Bike share ridership 2021-09.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name    716
# end_station_id        184
# end_time                0
# end_station_name      909
# bike_id                 0
# user_type               0
# dtype: int64
#
# Bike share ridership 2021-10.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name    434
# end_station_id        192
# end_time                0
# end_station_name      674
# bike_id                 0
# user_type               0
# dtype: int64
#
# Bike share ridership 2021-11.csv
# trip_id                  0
# trip_duration            0
# start_station_id         0
# start_time               0
# start_station_name    1068
# end_station_id         110
# end_time                 0
# end_station_name      1255
# bike_id                  0
# user_type                0
# dtype: int64
#
# Bike share ridership 2021-12.csv
# trip_id                  0
# trip_duration            0
# start_station_id         0
# start_time               0
# start_station_name    1160
# end_station_id         101
# end_time                 0
# end_station_name      1375
# bike_id                  0
# user_type                0
# dtype: int64
#
# Bike share ridership 2022-01.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name    570
# end_station_id        116
# end_time                0
# end_station_name      748
# bike_id                 0
# user_type               0
# dtype: int64
#
# Bike share ridership 2022-02.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name    599
# end_station_id         51
# end_time                0
# end_station_name      734
# bike_id                 0
# user_type               0
# dtype: int64
#
# Bike share ridership 2022-03.csv
# trip_id                  0
# trip_duration            0
# start_station_id         0
# start_time               0
# start_station_name    1710
# end_station_id          46
# end_time                 0
# end_station_name      1957
# bike_id                  0
# user_type                0
# dtype: int64
#
# Bike share ridership 2022-04.csv
# trip_id                  0
# trip_duration            0
# start_station_id         0
# start_time               0
# start_station_name    4415
# end_station_id          43
# end_time                 0
# end_station_name      4548
# bike_id                  0
# user_type                0
# dtype: int64
#
# Bike share ridership 2022-05.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    11807
# end_station_id           84
# end_time                  0
# end_station_name      12226
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2022-06.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    17952
# end_station_id          121
# end_time                  0
# end_station_name      18370
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2022-07.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    22646
# end_station_id          104
# end_time                  0
# end_station_name      22978
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2022-08.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    32764
# end_station_id          130
# end_time                  0
# end_station_name      32775
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2022-09.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    32313
# end_station_id          150
# end_time                  0
# end_station_name      32356
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2022-10.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    27930
# end_station_id          181
# end_time                  0
# end_station_name      27546
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2022-11.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    19687
# end_station_id          160
# end_time                  0
# end_station_name      19431
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2022-12.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    11073
# end_station_id           93
# end_time                  0
# end_station_name      11297
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2023-01.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    10630
# end_station_id          103
# end_time                  0
# end_station_name      10808
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2023-02.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    10872
# end_station_id           60
# end_time                  0
# end_station_name      11219
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2023-03.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    15446
# end_station_id           80
# end_time                  0
# end_station_name      15942
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2023-04.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    31396
# end_station_id          172
# end_time                  0
# end_station_name      31609
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2023-05.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    51679
# end_station_id          193
# end_time                  0
# end_station_name      51761
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2023-06.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    66522
# end_station_id          209
# end_time                  0
# end_station_name      66969
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2023-07.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    79068
# end_station_id          292
# end_time                  0
# end_station_name      79178
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2023-08.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    87075
# end_station_id          412
# end_time                  0
# end_station_name      86871
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2023-09.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    89717
# end_station_id          548
# end_time                  0
# end_station_name      90312
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2023-10.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    71640
# end_station_id          406
# end_time                  0
# end_station_name      72479
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2023-11.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    47861
# end_station_id          233
# end_time                  0
# end_station_name      48003
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2023-12.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    33169
# end_station_id          236
# end_time                  0
# end_station_name      33412
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2024-01.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    28213
# end_station_id           95
# end_time                  0
# end_station_name      28228
# bike_id                   0
# user_type                 0
# dtype: int64
#
# Bike share ridership 2024-02.csv
# trip_id                0
# trip_duration          0
# start_station_id       0
# start_time             0
# start_station_name    29
# end_station_id         0
# end_time               0
# end_station_name      32
# bike_id                0
# user_type              0
# model                  0
# dtype: int64
#
# Bike share ridership 2024-04.csv
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name    696
# end_station_id          0
# end_time                0
# end_station_name      836
# bike_id                 0
# user_type               0
# model                   0
# dtype: int64
#
# Bike share ridership 2024-05.csv
# trip_id                0
# trip_duration          0
# start_station_id       0
# start_time             0
# start_station_name    34
# end_station_id         0
# end_time               0
# end_station_name      38
# bike_id                0
# user_type              0
# model                  0
# dtype: int64
#
# Bike share ridership 2024-06.csv
# trip_id                  0
# trip_duration            0
# start_station_id         0
# start_time               0
# start_station_name    4480
# end_station_id           0
# end_time                 0
# end_station_name      4499
# bike_id                  0
# user_type                0
# model                 1936
# dtype: int64
#
# Bike share ridership 2024-07.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    20663
# end_station_id            0
# end_time                  0
# end_station_name      21217
# bike_id                   0
# user_type                 0
# model                  2802
# dtype: int64
#
# Bike share ridership 2024-08.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    28201
# end_station_id            0
# end_time                  0
# end_station_name      28569
# bike_id                   0
# user_type                 0
# model                  2383
# dtype: int64
#
# Bike share ridership 2024-09.csv
# trip_id                   0
# trip_duration             0
# start_station_id          0
# start_time                0
# start_station_name    30645
# end_station_id            0
# end_time                  0
# end_station_name      31423
# bike_id                   0
# user_type                 0
# model                  3171
# dtype: int64

# %%
dat2017, dat2018, dat2019, dat2020, dat2021, dat2022, dat2023, dat2024 = data.unpack()

# %%
# 2017 Q4
dat2017_q4 = dat2017.get_data_files('Bikeshare Ridership (2017 Q4).csv')
dat2017_q4[dat2017_q4['end_station_name'].isnull()]
# Out:
#         trip_id         start_time  end_time  trip_duration  \
# 295638  2302635  11/29/17 05:53:54  NULLNULL              0
#
#              start_station_name end_station_name user_type
# 295638  Seaton St / Dundas St E              NaN    Casual

# %%
dat2017_q4['end_time'] = pd.to_datetime(dat2017_q4['end_time'], format='%m/%d/%y %H:%M:%S', errors='coerce')
# dat2017_q4['end_time'] = pd.to_datetime(dat2017_q4['end_time'], errors='coerce')
dat2017_q4[dat2017_q4['end_time'].isna()]
# Out:
#         trip_id         start_time end_time  trip_duration  \
# 295638  2302635  11/29/17 05:53:54      NaT              0
#
#              start_station_name end_station_name user_type
# 295638  Seaton St / Dundas St E              NaN    Casual

# %%
anomaly_entries = pd.DataFrame(columns=column_order)
anomaly_entries = pd.concat([anomaly_entries, dat2017_q4[dat2017_q4['end_time'].isna()]], ignore_index=True)
dat2017_q4.dropna(subset=['end_time'], inplace=True)
anomaly_entries.head()
# Out:
#    trip_id trip_duration start_station_id         start_time  \
# 0  2302635             0              NaN  11/29/17 05:53:54
#
#         start_station_name end_station_id end_time end_station_name bike_id  \
# 0  Seaton St / Dundas St E            NaN      NaN              NaN     NaN
#
#   user_type model
# 0    Casual   NaN

# %%
for df in dat2017.get_data_files():
    print(df[df['trip_duration'] == 0])
# Out:
# Empty DataFrame
# Columns: [trip_id, start_time, end_time, trip_duration, start_station_id, start_station_name, end_station_id, end_station_name, user_type]
# Index: []
# Empty DataFrame
# Columns: [trip_id, start_time, end_time, trip_duration, start_station_id, start_station_name, end_station_id, end_station_name, user_type]
# Index: []
# Empty DataFrame
# Columns: [trip_id, start_time, end_time, trip_duration, start_station_name, end_station_name, user_type]
# Index: []
# Empty DataFrame
# Columns: [trip_id, start_time, end_time, trip_duration, start_station_name, end_station_name, user_type]
# Index: []

# %%
print("trip_duration")
for fname, df in dat2019.list_data_files().items():
    print(f"\n{fname}\nNum Missing Values: {df['trip_duration'].isna().sum()}")
    print(df[df['trip_duration'].isna()].head())
# Out:
# trip_duration
#
# 2019-Q1.csv
# Num Missing Values: 7
# 59771    NaN
# 74933    NaN
# 78219    NaN
# 86634    NaN
# 120157   NaN
# Name: trip_duration, dtype: float64
#
# 2019-Q2.csv
# Num Missing Values: 4
# 123305   NaN
# 206892   NaN
# 218836   NaN
# 303891   NaN
# Name: trip_duration, dtype: float64
#
# 2019-Q3.csv
# Num Missing Values: 3
# 449577   NaN
# 834139   NaN
# 908535   NaN
# Name: trip_duration, dtype: float64
#
# 2019-Q4.csv
# Num Missing Values: 2
# 227766   NaN
# 444309   NaN
# Name: trip_duration, dtype: float64

# %%
for fname, df in dat2019.list_data_files().items():
    # adjust to fill with end - start time
    df['trip_duration'] = df['trip_duration'].fillna(0)
    print(f"{fname}\nNum Missing Values: {df['trip_duration'].isna().sum()}")
    print(f"Can convert all: {(df['trip_duration'] % 1 == 0).all()}\n")
# Out:
# 2019-Q1.csv
# Num Missing Values: 0
# Can convert all: True
#
# 2019-Q2.csv
# Num Missing Values: 0
# Can convert all: True
#
# 2019-Q3.csv
# Num Missing Values: 0
# Can convert all: True
#
# 2019-Q4.csv
# Num Missing Values: 0
# Can convert all: True

# %%
for df in dat2019.get_data_files():
    df['trip_duration'] = df['trip_duration'].astype('int64')
    print(f"Trip Duration: {df['trip_duration'].dtype}")
# Out:
# Trip Duration: int64
# Trip Duration: int64
# Trip Duration: int64
# Trip Duration: int64

# %%
print("start_station_id dtype")
for fname, df in dat2020.list_data_files().items():
    print(f"{fname}: {df['start_station_id'].dtype}")
# Out:
# start_station_id dtype
# 2020-01.csv: int64
# 2020-02.csv: int64
# 2020-03.csv: int64
# 2020-04.csv: int64
# 2020-05.csv: int64
# 2020-06.csv: int64
# 2020-07.csv: int64
# 2020-08.csv: int64
# 2020-09.csv: int64
# 2020-10.csv: object
# 2020-11.csv: int64
# 2020-12.csv: int64

# %%
df_2020_10 = dat2020.get_data_files("2020-10.csv")
df_2020_10.dtypes
# Out:
# trip_id                int64
# trip_duration          int64
# start_station_id      object
# start_time            object
# start_station_name    object
# end_station_id        object
# end_time              object
# end_station_name      object
# bike_id               object
# user_type             object
# dtype: object

# %%
df_2020_10 = dat2020.get_data_files("2020-10.csv")
df_2020_10_copy = df_2020_10[['start_station_id']].copy()
df_2020_10_copy['numeric'] = pd.to_numeric(df_2020_10_copy['start_station_id'], errors='coerce')

anomaly = df_2020_10_copy[df_2020_10_copy['numeric'].isna()]
anomaly[['start_station_id']]
# Out:
#         start_station_id
# 25640   10/03/2020 13:28
# 25837   10/03/2020 13:38
# 26029   10/03/2020 13:48
# 26248   10/03/2020 13:58
# 26560   10/03/2020 14:12
# ...                  ...
# 266879  10/30/2020 17:01
# 268551  10/30/2020 19:42
# 275974  10/31/2020 18:00
# 277412  10/31/2020 21:27
# 277472  10/31/2020 21:43
#
# [249 rows x 1 columns]

# %%
df_2020_10.head()
# Out:
#    trip_id  trip_duration start_station_id        start_time  \
# 0  9970495            918             7418  10/01/2020 00:00
# 1  9970496            662             7061  10/01/2020 00:00
# 2  9970497            525             7051  10/01/2020 00:01
# 3  9970498            382             7004  10/01/2020 00:01
# 4  9970499            417             7051  10/01/2020 00:01
#
#                     start_station_name end_station_id          end_time  \
# 0     College Park - Yonge St Entrance           7007  10/01/2020 00:15
# 1               Dalton Rd / Bloor St W           7143  10/01/2020 00:11
# 2  Wellesley St E / Yonge St (Green P)           7009  10/01/2020 00:09
# 3              University Ave / Elm St           7050  10/01/2020 00:07
# 4  Wellesley St E / Yonge St (Green P)           7292  10/01/2020 00:08
#
#                     end_station_name bike_id      user_type
# 0              College St / Huron St    5677  Annual Member
# 1           Kendal Ave / Bernard Ave    6634  Annual Member
# 2              King St E / Jarvis St    4560  Annual Member
# 3  Richmond St E / Jarvis St Green P    4948  Annual Member
# 4      Granby St / Church St - SMART    5400  Annual Member

# %%
anomaly_subset = df_2020_10.loc[anomaly.index]
anomaly_subset
# Out:
#             trip_id  trip_duration  start_station_id  \
# 25640   10000084625           7120  10/03/2020 13:28
# 25837   10000306555           7120  10/03/2020 13:38
# 26029   10000519608           7576  10/03/2020 13:48
# 26248   10000755851           7357  10/03/2020 13:58
# 26560   10001076784           7313  10/03/2020 14:12
# ...             ...            ...               ...
# 266879  10281521317           7417  10/30/2020 17:01
# 268551  10283383488           7017  10/30/2020 19:42
# 275974  10291748450           7417  10/31/2020 18:00
# 277412  10293410950           7474  10/31/2020 21:27
# 277472  10293474102           7015  10/31/2020 21:43
#
#                               start_time start_station_name    end_station_id  \
# 25640            Gerrard St E / River St               7120  10/03/2020 13:38
# 25837            Gerrard St E / River St               7576  10/03/2020 13:48
# 26029        Front St E / Bayview Avenue               7357  10/03/2020 13:58
# 26248      Lake Shore Blvd E / Leslie St               7313  10/03/2020 14:12
# 26560   Coxwell Ave /  Lake Shore Blvd E               7317  10/03/2020 14:26
# ...                                  ...                ...               ...
# 266879             King St W / Jordan St               7253  10/30/2020 17:06
# 268551         Widmer St / Adelaide St W               7417  10/30/2020 19:50
# 275974             King St W / Jordan St               7474  10/31/2020 18:07
# 277412                   Clarence Square               7015  10/31/2020 21:42
# 277472    King St W / Bay St (West Side)               7417  10/31/2020 21:44
#
#                                 end_time end_station_name        bike_id  \
# 25640            Gerrard St E / River St             5250  Annual Member
# 25837        Front St E / Bayview Avenue             5250  Annual Member
# 26029      Lake Shore Blvd E / Leslie St             5250  Annual Member
# 26248   Coxwell Ave /  Lake Shore Blvd E             5250  Annual Member
# 26560           Hubbard Blvd / Balsam Av             5250  Annual Member
# ...                                  ...              ...            ...
# 266879      John St  / Mercer St - SMART             4888  Annual Member
# 268551             King St W / Jordan St             5835  Annual Member
# 275974                   Clarence Square             3814  Annual Member
# 277412    King St W / Bay St (West Side)             3771  Annual Member
# 277472             King St W / Jordan St             3771  Annual Member
#
#        user_type
# 25640        NaN
# 25837        NaN
# 26029        NaN
# 26248        NaN
# 26560        NaN
# ...          ...
# 266879       NaN
# 268551       NaN
# 275974       NaN
# 277412       NaN
# 277472       NaN
#
# [249 rows x 10 columns]

# %%
# double check consistency
anomaly_subset['user_type'].isnull().sum() == df_2020_10['user_type'].isnull().sum()
# Out:
# np.True_

# %%
# fill with 0 instead of NaN to maintain column type int64, we will be mapping to these indexes directly
df_2020_10.iloc[anomaly.index, 1:] = df_2020_10.iloc[anomaly.index, 1:].shift(periods=1, fill_value=0, axis='columns')
df_2020_10.iloc[anomaly.index]
# Out:
#             trip_id  trip_duration start_station_id        start_time  \
# 25640   10000084625              0             7120  10/03/2020 13:28
# 25837   10000306555              0             7120  10/03/2020 13:38
# 26029   10000519608              0             7576  10/03/2020 13:48
# 26248   10000755851              0             7357  10/03/2020 13:58
# 26560   10001076784              0             7313  10/03/2020 14:12
# ...             ...            ...              ...               ...
# 266879  10281521317              0             7417  10/30/2020 17:01
# 268551  10283383488              0             7017  10/30/2020 19:42
# 275974  10291748450              0             7417  10/31/2020 18:00
# 277412  10293410950              0             7474  10/31/2020 21:27
# 277472  10293474102              0             7015  10/31/2020 21:43
#
#                       start_station_name end_station_id          end_time  \
# 25640            Gerrard St E / River St           7120  10/03/2020 13:38
# 25837            Gerrard St E / River St           7576  10/03/2020 13:48
# 26029        Front St E / Bayview Avenue           7357  10/03/2020 13:58
# 26248      Lake Shore Blvd E / Leslie St           7313  10/03/2020 14:12
# 26560   Coxwell Ave /  Lake Shore Blvd E           7317  10/03/2020 14:26
# ...                                  ...            ...               ...
# 266879             King St W / Jordan St           7253  10/30/2020 17:06
# 268551         Widmer St / Adelaide St W           7417  10/30/2020 19:50
# 275974             King St W / Jordan St           7474  10/31/2020 18:07
# 277412                   Clarence Square           7015  10/31/2020 21:42
# 277472    King St W / Bay St (West Side)           7417  10/31/2020 21:44
#
#                         end_station_name bike_id      user_type
# 25640            Gerrard St E / River St    5250  Annual Member
# 25837        Front St E / Bayview Avenue    5250  Annual Member
# 26029      Lake Shore Blvd E / Leslie St    5250  Annual Member
# 26248   Coxwell Ave /  Lake Shore Blvd E    5250  Annual Member
# 26560           Hubbard Blvd / Balsam Av    5250  Annual Member
# ...                                  ...     ...            ...
# 266879      John St  / Mercer St - SMART    4888  Annual Member
# 268551             King St W / Jordan St    5835  Annual Member
# 275974                   Clarence Square    3814  Annual Member
# 277412    King St W / Bay St (West Side)    3771  Annual Member
# 277472             King St W / Jordan St    3771  Annual Member
#
# [249 rows x 10 columns]

# %%
start_time = pd.to_datetime(df_2020_10.loc[anomaly.index, 'start_time'])
end_time = pd.to_datetime(df_2020_10.loc[anomaly.index, 'end_time'])
trip_dur = (end_time - start_time).dt.total_seconds().astype('int64')

df_2020_10.loc[trip_dur.index, 'trip_duration'] = trip_dur
df_2020_10.loc[trip_dur.index]
# Out:
#             trip_id  trip_duration start_station_id        start_time  \
# 25640   10000084625            600             7120  10/03/2020 13:28
# 25837   10000306555            600             7120  10/03/2020 13:38
# 26029   10000519608            600             7576  10/03/2020 13:48
# 26248   10000755851            840             7357  10/03/2020 13:58
# 26560   10001076784            840             7313  10/03/2020 14:12
# ...             ...            ...              ...               ...
# 266879  10281521317            300             7417  10/30/2020 17:01
# 268551  10283383488            480             7017  10/30/2020 19:42
# 275974  10291748450            420             7417  10/31/2020 18:00
# 277412  10293410950            900             7474  10/31/2020 21:27
# 277472  10293474102             60             7015  10/31/2020 21:43
#
#                       start_station_name end_station_id          end_time  \
# 25640            Gerrard St E / River St           7120  10/03/2020 13:38
# 25837            Gerrard St E / River St           7576  10/03/2020 13:48
# 26029        Front St E / Bayview Avenue           7357  10/03/2020 13:58
# 26248      Lake Shore Blvd E / Leslie St           7313  10/03/2020 14:12
# 26560   Coxwell Ave /  Lake Shore Blvd E           7317  10/03/2020 14:26
# ...                                  ...            ...               ...
# 266879             King St W / Jordan St           7253  10/30/2020 17:06
# 268551         Widmer St / Adelaide St W           7417  10/30/2020 19:50
# 275974             King St W / Jordan St           7474  10/31/2020 18:07
# 277412                   Clarence Square           7015  10/31/2020 21:42
# 277472    King St W / Bay St (West Side)           7417  10/31/2020 21:44
#
#                         end_station_name bike_id      user_type
# 25640            Gerrard St E / River St    5250  Annual Member
# 25837        Front St E / Bayview Avenue    5250  Annual Member
# 26029      Lake Shore Blvd E / Leslie St    5250  Annual Member
# 26248   Coxwell Ave /  Lake Shore Blvd E    5250  Annual Member
# 26560           Hubbard Blvd / Balsam Av    5250  Annual Member
# ...                                  ...     ...            ...
# 266879      John St  / Mercer St - SMART    4888  Annual Member
# 268551             King St W / Jordan St    5835  Annual Member
# 275974                   Clarence Square    3814  Annual Member
# 277412    King St W / Bay St (West Side)    3771  Annual Member
# 277472             King St W / Jordan St    3771  Annual Member
#
# [249 rows x 10 columns]

# %%
df_2020_10.dtypes
# Out:
# trip_id                int64
# trip_duration          int64
# start_station_id      object
# start_time            object
# start_station_name    object
# end_station_id        object
# end_time              object
# end_station_name      object
# bike_id               object
# user_type             object
# dtype: object

# %%
df_2020_10.isnull().sum()
# Out:
# trip_id                 0
# trip_duration           0
# start_station_id        0
# start_time              0
# start_station_name    164
# end_station_id         60
# end_time                0
# end_station_name      202
# bike_id                 0
# user_type               0
# dtype: int64

# %%
df_2020_10[df_2020_10['end_station_id'].isnull()].head()
# Out:
#         trip_id  trip_duration start_station_id        start_time  \
# 18189   9991564              0             7235  10/02/2020 17:41
# 18629   9992026              0             7129  10/02/2020 18:15
# 23032   9997148         182515             7168  10/03/2020 10:30
# 23614   9997816              0             7391  10/03/2020 11:15
# 26512  10001030              0             7056  10/03/2020 14:10
#
#                             start_station_name end_station_id  \
# 18189  Bay St / College St (West Side) - SMART            NaN
# 18629                 Davenport Rd / Avenue Rd            NaN
# 23032                   Queens Quay / Yonge St            NaN
# 23614                     Yonge St / Dundas Sq            NaN
# 26512               Parliament St / Gerrard St            NaN
#
#                end_time end_station_name bike_id      user_type
# 18189  10/02/2020 17:41              NaN    6677  Annual Member
# 18629  10/02/2020 18:15              NaN    1031  Annual Member
# 23032  10/05/2020 13:12              NaN    4635  Annual Member
# 23614  10/03/2020 11:15              NaN    2977  Annual Member
# 26512  10/03/2020 14:10              NaN    6288  Annual Member

# %%
df_2020_10['trip_duration'].loc[df_2020_10['end_station_id'].isnull()].value_counts()
# Out:
# trip_duration
# 0         54
# 182515     1
# 587862     1
# 775107     1
# 686918     1
# 273235     1
# 252375     1
# Name: count, dtype: int64

# %%
df_2020_10[['end_station_id', 'end_station_name']].loc[df_2020_10['end_station_id'].isnull()].isnull().sum()
# Out:
# end_station_id      60
# end_station_name    60
# dtype: int64

# %%
df_2020_10.loc[df_2020_10['start_station_id'] == df_2020_10['end_station_id']].shape[0]
# Out:
# 12017

# %%
df_2020_10.loc[df_2020_10['trip_duration'] == 0].shape[0]
# Out:
# 133

# %%
# adjust dtype of Start Station Id, End Station Id, Bike Id
# datetimes will be adjusted later with all data files, first adjustment found at [11]

# %% [markdown]
# Identify inconsistent column names across files within each year.
#
# Detect presence of non-standard headers, placeholder rows, or encoding issues.
#
# Check if date/time ranges are coherent (e.g., all monthly files span the full year
#
# Column renaming/standardization
#
# Missing column insertion
#
# Type enforcement
#
# Datetime parsing
#
# Concate all df per year
#
# Validate schema consistency
#
# Save
